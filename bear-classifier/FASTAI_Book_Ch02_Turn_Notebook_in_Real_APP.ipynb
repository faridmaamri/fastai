# %% [markdown]
# <a href="https://colab.research.google.com/github/faridmaamri/fastai/blob/main/bear-classifier/FASTAI_Book_Ch02_Turn_Notebook_in_Real_APP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# This notebook purpose is to be used to create a simple Web App that using the bear classifer  trained model.
#
# this notebook will be  used on : [mybinder platform](https://mybinder.org/) to create teh webapp.
#
# mybiner url: https://mybinder.org/

# %%
# !pip install -r requirements.txt

# %% [markdown]
# **Import required librarie**

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# **Import the bear classifier model**

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl',cpu=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4458/4270610858.py in <cell line: 0>()
#       1 path = Path()
# ----> 2 learn_inf = load_learner(path/'export.pkl',cpu=True)
#
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py in load_learner(fname, cpu, pickle_module)
# ...

# %% [markdown]
# **Initialize the widgets**

# %%
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
btn_run = widgets.Button(description='Classify')
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %% [markdown]
# **Create the App**

# %%
#hide_output
display(VBox([widgets.Label('Select your bear!'),
      btn_upload, btn_run, out_pl, lbl_pred]))
# Out:
# ...
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
# ...
